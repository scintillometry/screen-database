# %%
from plot_screens import plot_screens_3D, summary_plots
import pandas as pd
# %matplotlib notebook

# %%
sources = pd.read_csv('pulsars-with-screens.csv')
screens = pd.read_csv('screens-database.csv')

# %%
plot_screens_3D(sources,screens)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
summary_plots(sources,screens)
# Out:
# <img src="data:image/png;base64,..." width="750">
